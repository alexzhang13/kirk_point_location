# %%
import time

from algos import (
    angular_random,
    iterative_hull
)

# %%
# For n = 10, Randomized Circles
n = 10
start = time.time()
poly = angular_random(n)
end = time.time()
print('Time for Alg 1, n=10:', end - start, 'seconds')
poly.visualize(color='g-')
# Out:
# Time for Alg 1, n=10: 0.003175020217895508 seconds

# %%
# For n = 100, Randomized Circles
n = 100
start = time.time()
poly = angular_random(n)
end = time.time()
print('Time for Alg 1, n=100:', end - start, 'seconds')
poly.visualize(color='g-')
# Out:
# Time for Alg 1, n=100: 0.0023059844970703125 seconds

# %%
# For n = 1000, Randomized Circles
n = 1000
start = time.time()
poly = angular_random(n)
end = time.time()
print('Time for Alg 1, n=1000:', end - start, 'seconds')
poly.visualize(color='g-')
# Out:
# Time for Alg 1, n=1000: 0.005237102508544922 seconds

# %%
# For n = 10000, Randomized Circles
n = 10000
start = time.time()
poly = angular_random(n)
end = time.time()
print('Time for Alg 1, n=10000:', end - start, 'seconds')
poly.visualize(color='g-')
# Out:
# Time for Alg 1, n=10000: 0.03402304649353027 seconds

# %%
# For n = 10, Iterative Edges
n = 10
start = time.time()
poly = iterative_hull(n)
end = time.time()
print('Time for Alg 2, n=10:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2, n=10: 0.0018808841705322266 seconds

# %%
# For n = 100, Iterative Edges
n = 100
start = time.time()
poly = iterative_hull(n)
end = time.time()
print('Time for Alg 2, n=100:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2, n=100: 0.16569995880126953 seconds

# %%
# For n = 1000, Iterative Edges
n = 1000
start = time.time()
poly = iterative_hull(n)
end = time.time()
print('Time for Alg 2, n=1000:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2, n=1000: 34.57695412635803 seconds

# %%
# For n = 1000, Iterative Edges w/ Gauss Init
n = 1000
start = time.time()
poly = iterative_hull(n, init='gauss')
end = time.time()
print('Time for Alg 2 w/ Gauss init, n=1000:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2 w/ Gauss init, n=1000: 19.162890911102295 seconds

# %%
# For n = 1000, Iterative Edges w/ beta
n = 1000
start = time.time()
poly = iterative_hull(n, init='beta')
end = time.time()
print('Time for Alg 2 w/ Beta init, n=1000:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2 w/ Beta init, n=1000: 16.7255859375 seconds
