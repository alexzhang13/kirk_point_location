# %%
import time

from algos import (
    angular_random,
    iterative_hull
)

# %%
# For n = 10, Randomized Circles
n = 10
start = time.time()
poly = angular_random(n)
end = time.time()
print('Time for Alg 1, n=10:', end - start, 'seconds')
poly.visualize(color='g-')
# Out:
# Time for Alg 1, n=10: 0.0014150142669677734 seconds

# %%
# For n = 100, Randomized Circles
n = 100
start = time.time()
poly = angular_random(n)
end = time.time()
print('Time for Alg 1, n=100:', end - start, 'seconds')
poly.visualize(color='g-')
# Out:
# Time for Alg 1, n=100: 0.0012767314910888672 seconds

# %%
# For n = 1000, Randomized Circles
n = 1000
start = time.time()
poly = angular_random(n)
end = time.time()
print('Time for Alg 1, n=1000:', end - start, 'seconds')
poly.visualize(color='g-')
# Out:
# Time for Alg 1, n=1000: 0.004959821701049805 seconds

# %%
# For n = 10000, Randomized Circles
n = 10000
start = time.time()
poly = angular_random(n)
end = time.time()
print('Time for Alg 1, n=10000:', end - start, 'seconds')
poly.visualize(color='g-')
# Out:
# Time for Alg 1, n=10000: 0.03356003761291504 seconds

# %%
# For n = 10, Iterative Edges
n = 10
start = time.time()
poly = iterative_hull(n)
end = time.time()
print('Time for Alg 2, n=10:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2, n=10: 0.0019412040710449219 seconds

# %%
# For n = 100, Iterative Edges
n = 100
start = time.time()
poly = iterative_hull(n)
end = time.time()
print('Time for Alg 2, n=100:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2, n=100: 0.12721514701843262 seconds

# %%
# For n = 1000, Iterative Edges
n = 1000
start = time.time()
poly = iterative_hull(n)
end = time.time()
print('Time for Alg 2, n=1000:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2, n=1000: 15.632301092147827 seconds

# %%
# For n = 1000, Iterative Edges w/ Gauss Init
n = 1000
start = time.time()
poly = iterative_hull(n, init='gauss')
end = time.time()
print('Time for Alg 2 w/ Gauss init, n=1000:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2 w/ Gauss init, n=1000: 15.785009860992432 seconds

# %%
# For n = 1000, Iterative Edges w/ beta
n = 1000
start = time.time()
poly = iterative_hull(n, init='beta')
end = time.time()
print('Time for Alg 2 w/ Beta init, n=1000:', end - start, 'seconds')
poly.visualize(color='r-')
# Out:
# Time for Alg 2 w/ Beta init, n=1000: 16.790940761566162 seconds
